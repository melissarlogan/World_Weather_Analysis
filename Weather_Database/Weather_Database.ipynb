# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
lats= np.random.uniform(-90.000,90.000, size=2000)
lngs= np.random.uniform(-180.000,180.000, size=2000)
lat_lngs= zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 725

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d7e038af9cbfce4820daa1b342a8b468

# %%
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description= city_weather ['weather'][0]['description']
        
        # Append the city information into city_data list.
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country})
# If an error is experienced, skip the city.
    except Exception as e:
        print("City not found. Skipping...")
        print(e)
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | severo-kurilsk
# Processing Record 2 of Set 1 | san patricio
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | la ronge
# Processing Record 6 of Set 1 | fortuna
# Processing Record 7 of Set 1 | sorland
# Processing Record 8 of Set 1 | grindavik
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | ribeira grande
# Processing Record 11 of Set 1 | pisco
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | rio grande
# Processing Record 15 of Set 1 | northam
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | cherskiy
# Processing Record 18 of Set 1 | tuktoyaktuk
# Processing Record 19 of Set 1 | atambua
# Processing Record 20 of Set 1 | te anau
# Processing Record 21 of Set 1 | guerrero negro
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | warrington
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | mount isa
# Processing Record 27 of Set 1 | souillac
# Processing Record 28 of Set 1 | kangaatsiaq
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | pasighat
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | kahului
# Processing Record 34 of Set 1 | port moresby
# Processing Record 35 of Set 1 | diebougou
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | dekoa
# City not found. Skipping...
# 'coord'
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | mizdah
# Processing Record 40 of Set 1 | pangai
# Processing Record 41 of Set 1 | sioux lookout
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# 'coord'
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# 'coord'
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | coihaique
# Processing Record 46 of Set 1 | padang
# Processing Record 47 of Set 1 | belyy yar
# Processing Record 48 of Set 1 | oranjemund
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | lebu
# Processing Record 1 of Set 2 | ergani
# Processing Record 2 of Set 2 | kuching
# Processing Record 3 of Set 2 | cam ranh
# Processing Record 4 of Set 2 | nanortalik
# Processing Record 5 of Set 2 | amderma
# City not found. Skipping...
# 'coord'
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | chumikan
# Processing Record 8 of Set 2 | smithers
# Processing Record 9 of Set 2 | saskylakh
# Processing Record 10 of Set 2 | rikitea
# Processing Record 11 of Set 2 | nizhneyansk
# City not found. Skipping...
# 'coord'
# Processing Record 12 of Set 2 | khatanga
# Processing Record 13 of Set 2 | rudnaya pristan
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | la union
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | port lincoln
# Processing Record 19 of Set 2 | husavik
# Processing Record 20 of Set 2 | maamba
# Processing Record 21 of Set 2 | axim
# Processing Record 22 of Set 2 | mataura
# Processing Record 23 of Set 2 | diego de almagro
# Processing Record 24 of Set 2 | pamekasan
# Processing Record 25 of Set 2 | ulladulla
# Processing Record 26 of Set 2 | magadan
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | sentyabrskiy
# City not found. Skipping...
# 'coord'
# Processing Record 29 of Set 2 | havelock
# Processing Record 30 of Set 2 | leningradskiy
# Processing Record 31 of Set 2 | ingham
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | bathsheba
# Processing Record 35 of Set 2 | chuy
# Processing Record 36 of Set 2 | atuona
# Processing Record 37 of Set 2 | bambous virieux
# Processing Record 38 of Set 2 | wuan
# Processing Record 39 of Set 2 | norman wells
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | hambantota
# Processing Record 43 of Set 2 | santa isabel do rio negro
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | kampene
# Processing Record 46 of Set 2 | yamada
# Processing Record 47 of Set 2 | kovur
# Processing Record 48 of Set 2 | alofi
# Processing Record 49 of Set 2 | port hedland
# Processing Record 50 of Set 2 | luderitz
# Processing Record 1 of Set 3 | madison heights
# Processing Record 2 of Set 3 | olafsvik
# Processing Record 3 of Set 3 | aklavik
# Processing Record 4 of Set 3 | san quintin
# Processing Record 5 of Set 3 | fare
# Processing Record 6 of Set 3 | katsuura
# Processing Record 7 of Set 3 | ternate
# Processing Record 8 of Set 3 | barentsburg
# City not found. Skipping...
# 'coord'
# Processing Record 9 of Set 3 | djibo
# Processing Record 10 of Set 3 | rabo de peixe
# Processing Record 11 of Set 3 | artyk
# City not found. Skipping...
# 'coord'
# Processing Record 12 of Set 3 | margate
# Processing Record 13 of Set 3 | horqueta
# Processing Record 14 of Set 3 | waw
# Processing Record 15 of Set 3 | coquimbo
# Processing Record 16 of Set 3 | ostrovnoy
# Processing Record 17 of Set 3 | grand gaube
# Processing Record 18 of Set 3 | sinnamary
# Processing Record 19 of Set 3 | den helder
# Processing Record 20 of Set 3 | lagdo
# Processing Record 21 of Set 3 | stornoway
# Processing Record 22 of Set 3 | scarborough
# Processing Record 23 of Set 3 | bargal
# City not found. Skipping...
# 'coord'
# Processing Record 24 of Set 3 | phan thiet
# Processing Record 25 of Set 3 | waingapu
# Processing Record 26 of Set 3 | abu kamal
# Processing Record 27 of Set 3 | belushya guba
# City not found. Skipping...
# 'coord'
# Processing Record 28 of Set 3 | aban
# Processing Record 29 of Set 3 | springdale
# Processing Record 30 of Set 3 | henties bay
# Processing Record 31 of Set 3 | paamiut
# Processing Record 32 of Set 3 | puerto leguizamo
# Processing Record 33 of Set 3 | provideniya
# Processing Record 34 of Set 3 | castro
# Processing Record 35 of Set 3 | touros
# Processing Record 36 of Set 3 | saint george
# Processing Record 37 of Set 3 | hay river
# Processing Record 38 of Set 3 | luganville
# Processing Record 39 of Set 3 | cayenne
# Processing Record 40 of Set 3 | suoyarvi
# Processing Record 41 of Set 3 | mamallapuram
# Processing Record 42 of Set 3 | palabuhanratu
# City not found. Skipping...
# 'coord'
# Processing Record 43 of Set 3 | vanavara
# Processing Record 44 of Set 3 | batsfjord
# Processing Record 45 of Set 3 | nome
# Processing Record 46 of Set 3 | klaksvik
# Processing Record 47 of Set 3 | east london
# Processing Record 48 of Set 3 | bud
# Processing Record 49 of Set 3 | adrasmon
# Processing Record 50 of Set 3 | mudgee
# Processing Record 1 of Set 4 | kruisfontein
# Processing Record 2 of Set 4 | lompoc
# Processing Record 3 of Set 4 | hofn
# Processing Record 4 of Set 4 | tual
# Processing Record 5 of Set 4 | upernavik
# Processing Record 6 of Set 4 | kysyl-syr
# Processing Record 7 of Set 4 | havre
# Processing Record 8 of Set 4 | nioro
# Processing Record 9 of Set 4 | finote selam
# Processing Record 10 of Set 4 | skagastrond
# City not found. Skipping...
# 'coord'
# Processing Record 11 of Set 4 | vostok
# Processing Record 12 of Set 4 | namibe
# Processing Record 13 of Set 4 | narrabri
# Processing Record 14 of Set 4 | odienne
# Processing Record 15 of Set 4 | vestmannaeyjar
# Processing Record 16 of Set 4 | saint-philippe
# Processing Record 17 of Set 4 | port elizabeth
# Processing Record 18 of Set 4 | kodiak
# Processing Record 19 of Set 4 | cidreira
# Processing Record 20 of Set 4 | progreso
# Processing Record 21 of Set 4 | marsh harbour
# Processing Record 22 of Set 4 | nouadhibou
# Processing Record 23 of Set 4 | anadyr
# Processing Record 24 of Set 4 | itirapina
# Processing Record 25 of Set 4 | saint-augustin
# Processing Record 26 of Set 4 | port blair
# Processing Record 27 of Set 4 | cabo san lucas
# Processing Record 28 of Set 4 | dunedin
# Processing Record 29 of Set 4 | chokurdakh
# Processing Record 30 of Set 4 | sola
# Processing Record 31 of Set 4 | taltal
# Processing Record 32 of Set 4 | tucurui
# Processing Record 33 of Set 4 | yulara
# Processing Record 34 of Set 4 | puerto carreno
# Processing Record 35 of Set 4 | orissaare
# Processing Record 36 of Set 4 | neiva
# Processing Record 37 of Set 4 | berlevag
# Processing Record 38 of Set 4 | palmer
# Processing Record 39 of Set 4 | alto araguaia
# Processing Record 40 of Set 4 | kalininsk
# Processing Record 41 of Set 4 | havoysund
# Processing Record 42 of Set 4 | dolbeau
# City not found. Skipping...
# 'coord'
# Processing Record 43 of Set 4 | mangrol
# Processing Record 44 of Set 4 | pimentel
# Processing Record 45 of Set 4 | sulangan
# Processing Record 46 of Set 4 | moorhead
# Processing Record 47 of Set 4 | geraldton
# Processing Record 48 of Set 4 | danshui
# Processing Record 49 of Set 4 | kuche
# City not found. Skipping...
# 'coord'
# Processing Record 50 of Set 4 | katobu
# Processing Record 1 of Set 5 | bababe
# City not found. Skipping...
# 'coord'
# Processing Record 2 of Set 5 | beloha
# Processing Record 3 of Set 5 | vaitupu
# City not found. Skipping...
# 'coord'
# Processing Record 4 of Set 5 | kitimat
# Processing Record 5 of Set 5 | ponta do sol
# Processing Record 6 of Set 5 | tromso
# Processing Record 7 of Set 5 | ornes
# Processing Record 8 of Set 5 | teya
# Processing Record 9 of Set 5 | volot
# Processing Record 10 of Set 5 | zhezkazgan
# Processing Record 11 of Set 5 | asau
# Processing Record 12 of Set 5 | lata
# Processing Record 13 of Set 5 | genhe
# Processing Record 14 of Set 5 | sabibah
# City not found. Skipping...
# 'coord'
# Processing Record 15 of Set 5 | paso de los toros
# Processing Record 16 of Set 5 | tapaua
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 5 | mahebourg
# Processing Record 18 of Set 5 | port augusta
# Processing Record 19 of Set 5 | hailar
# Processing Record 20 of Set 5 | shubarkuduk
# Processing Record 21 of Set 5 | ancud
# Processing Record 22 of Set 5 | sao raimundo das mangabeiras
# Processing Record 23 of Set 5 | abha
# Processing Record 24 of Set 5 | el tigre
# Processing Record 25 of Set 5 | itarema
# Processing Record 26 of Set 5 | tumannyy
# City not found. Skipping...
# 'coord'
# Processing Record 27 of Set 5 | satitoa
# City not found. Skipping...
# 'coord'
# Processing Record 28 of Set 5 | darnah
# Processing Record 29 of Set 5 | hobart
# Processing Record 30 of Set 5 | attawapiskat
# City not found. Skipping...
# 'coord'
# Processing Record 31 of Set 5 | finschhafen
# Processing Record 32 of Set 5 | synya
# Processing Record 33 of Set 5 | conde
# Processing Record 34 of Set 5 | ambilobe
# Processing Record 35 of Set 5 | santa vitoria do palmar
# Processing Record 36 of Set 5 | kharovsk
# Processing Record 37 of Set 5 | carutapera
# Processing Record 38 of Set 5 | yantal
# Processing Record 39 of Set 5 | alnavar
# Processing Record 40 of Set 5 | dikson
# Processing Record 41 of Set 5 | nhulunbuy
# Processing Record 42 of Set 5 | burgeo
# Processing Record 43 of Set 5 | swan river
# Processing Record 44 of Set 5 | krasnoarmeysk
# Processing Record 45 of Set 5 | sibolga
# Processing Record 46 of Set 5 | mys shmidta
# City not found. Skipping...
# 'coord'
# Processing Record 47 of Set 5 | longyearbyen
# Processing Record 48 of Set 5 | omutinskoye
# City not found. Skipping...
# 'coord'
# Processing Record 49 of Set 5 | tocopilla
# Processing Record 50 of Set 5 | clyde river
# Processing Record 1 of Set 6 | da nang
# Processing Record 2 of Set 6 | halmstad
# Processing Record 3 of Set 6 | consett
# Processing Record 4 of Set 6 | quirinopolis
# Processing Record 5 of Set 6 | yellowknife
# Processing Record 6 of Set 6 | preobrazheniye
# Processing Record 7 of Set 6 | namatanai
# Processing Record 8 of Set 6 | bam
# Processing Record 9 of Set 6 | mehamn
# Processing Record 10 of Set 6 | esperance
# Processing Record 11 of Set 6 | tuatapere
# Processing Record 12 of Set 6 | prince rupert
# Processing Record 13 of Set 6 | erenhot
# Processing Record 14 of Set 6 | jiexiu
# Processing Record 15 of Set 6 | praia da vitoria
# Processing Record 16 of Set 6 | kavieng
# Processing Record 17 of Set 6 | nuuk
# Processing Record 18 of Set 6 | salinopolis
# Processing Record 19 of Set 6 | bardiyah
# Processing Record 20 of Set 6 | airai
# Processing Record 21 of Set 6 | mandalgovi
# Processing Record 22 of Set 6 | fort nelson
# Processing Record 23 of Set 6 | hithadhoo
# Processing Record 24 of Set 6 | marshfield
# Processing Record 25 of Set 6 | mujiayingzi
# Processing Record 26 of Set 6 | victoria
# Processing Record 27 of Set 6 | yar-sale
# Processing Record 28 of Set 6 | arraial do cabo
# Processing Record 29 of Set 6 | bowen
# Processing Record 30 of Set 6 | santa ana
# Processing Record 31 of Set 6 | aflu
# City not found. Skipping...
# 'coord'
# Processing Record 32 of Set 6 | peno
# Processing Record 33 of Set 6 | ahipara
# Processing Record 34 of Set 6 | dabola
# Processing Record 35 of Set 6 | yarmouth
# Processing Record 36 of Set 6 | kaitangata
# Processing Record 37 of Set 6 | umzimvubu
# City not found. Skipping...
# 'coord'
# Processing Record 38 of Set 6 | lavrentiya
# Processing Record 39 of Set 6 | pa sang
# Processing Record 40 of Set 6 | torbay
# Processing Record 41 of Set 6 | sao filipe
# Processing Record 42 of Set 6 | lazaro cardenas
# Processing Record 43 of Set 6 | rehoboth
# Processing Record 44 of Set 6 | ola
# Processing Record 45 of Set 6 | sembe
# Processing Record 46 of Set 6 | ilembo
# Processing Record 47 of Set 6 | port-gentil
# Processing Record 48 of Set 6 | pevek
# Processing Record 49 of Set 6 | maceio
# Processing Record 50 of Set 6 | tynda
# Processing Record 1 of Set 7 | ouegoa
# Processing Record 2 of Set 7 | pemangkat
# Processing Record 3 of Set 7 | half moon bay
# Processing Record 4 of Set 7 | laguna
# Processing Record 5 of Set 7 | srednekolymsk
# Processing Record 6 of Set 7 | banjar
# Processing Record 7 of Set 7 | camp verde
# Processing Record 8 of Set 7 | kununurra
# Processing Record 9 of Set 7 | dosso
# Processing Record 10 of Set 7 | iqaluit
# Processing Record 11 of Set 7 | faanui
# Processing Record 12 of Set 7 | narodychi
# Processing Record 13 of Set 7 | zagan
# Processing Record 14 of Set 7 | muisne
# Processing Record 15 of Set 7 | bandarbeyla
# Processing Record 16 of Set 7 | sobolevo
# Processing Record 17 of Set 7 | srostki
# Processing Record 18 of Set 7 | tottori
# Processing Record 19 of Set 7 | saleaula
# City not found. Skipping...
# 'coord'
# Processing Record 20 of Set 7 | saint-georges
# Processing Record 21 of Set 7 | beidao
# Processing Record 22 of Set 7 | bonthe
# Processing Record 23 of Set 7 | moron
# Processing Record 24 of Set 7 | himora
# City not found. Skipping...
# 'coord'
# Processing Record 25 of Set 7 | berdigestyakh
# Processing Record 26 of Set 7 | concordia
# Processing Record 27 of Set 7 | gat
# Processing Record 28 of Set 7 | matagami
# Processing Record 29 of Set 7 | tandil
# Processing Record 30 of Set 7 | piskivka
# Processing Record 31 of Set 7 | meulaboh
# Processing Record 32 of Set 7 | gimli
# Processing Record 33 of Set 7 | bilibino
# Processing Record 34 of Set 7 | solovetskiy
# City not found. Skipping...
# 'coord'
# Processing Record 35 of Set 7 | dingle
# Processing Record 36 of Set 7 | tautira
# Processing Record 37 of Set 7 | batagay-alyta
# Processing Record 38 of Set 7 | corrales
# Processing Record 39 of Set 7 | saldanha
# Processing Record 40 of Set 7 | eyl
# Processing Record 41 of Set 7 | joao pinheiro
# Processing Record 42 of Set 7 | alugan
# Processing Record 43 of Set 7 | calderitas
# Processing Record 44 of Set 7 | bitung
# Processing Record 45 of Set 7 | hamilton
# Processing Record 46 of Set 7 | vinukonda
# Processing Record 47 of Set 7 | maputo
# Processing Record 48 of Set 7 | aviles
# Processing Record 49 of Set 7 | nosy varika
# Processing Record 50 of Set 7 | tiksi
# Processing Record 1 of Set 8 | luanda
# Processing Record 2 of Set 8 | langham
# Processing Record 3 of Set 8 | kismayo
# Processing Record 4 of Set 8 | neiafu
# Processing Record 5 of Set 8 | pacific grove
# Processing Record 6 of Set 8 | samarai
# Processing Record 7 of Set 8 | manuk mangkaw
# Processing Record 8 of Set 8 | mantua
# Processing Record 9 of Set 8 | nivala
# Processing Record 10 of Set 8 | dakar
# Processing Record 11 of Set 8 | alzey
# Processing Record 12 of Set 8 | salalah
# Processing Record 13 of Set 8 | duncan
# Processing Record 14 of Set 8 | sahrak
# City not found. Skipping...
# 'coord'
# Processing Record 15 of Set 8 | deputatskiy
# Processing Record 16 of Set 8 | babanusah
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 8 | bonito
# Processing Record 18 of Set 8 | zaysan
# Processing Record 19 of Set 8 | trairi
# Processing Record 20 of Set 8 | ucluelet
# Processing Record 21 of Set 8 | fairbanks
# Processing Record 22 of Set 8 | nelson bay
# Processing Record 23 of Set 8 | fomboni
# Processing Record 24 of Set 8 | coruripe
# Processing Record 25 of Set 8 | zunyi
# Processing Record 26 of Set 8 | acajutla
# Processing Record 27 of Set 8 | antibes
# Processing Record 28 of Set 8 | samusu
# City not found. Skipping...
# 'coord'
# Processing Record 29 of Set 8 | lorengau
# Processing Record 30 of Set 8 | obsharovka
# Processing Record 31 of Set 8 | acarau
# Processing Record 32 of Set 8 | isangel
# Processing Record 33 of Set 8 | cockburn town
# Processing Record 34 of Set 8 | sitka
# Processing Record 35 of Set 8 | dicabisagan
# Processing Record 36 of Set 8 | dolgoderevenskoye
# Processing Record 37 of Set 8 | surman
# Processing Record 38 of Set 8 | sigli
# Processing Record 39 of Set 8 | savinka
# Processing Record 40 of Set 8 | morondava
# Processing Record 41 of Set 8 | tiznit
# Processing Record 42 of Set 8 | ahuimanu
# Processing Record 43 of Set 8 | adrar
# Processing Record 44 of Set 8 | balagansk
# Processing Record 45 of Set 8 | remontnoye
# Processing Record 46 of Set 8 | champerico
# Processing Record 47 of Set 8 | shingu
# Processing Record 48 of Set 8 | iseyin
# Processing Record 49 of Set 8 | meyungs
# City not found. Skipping...
# 'coord'
# Processing Record 50 of Set 8 | richards bay
# Processing Record 1 of Set 9 | tsihombe
# City not found. Skipping...
# 'coord'
# Processing Record 2 of Set 9 | mahibadhoo
# Processing Record 3 of Set 9 | alta floresta
# Processing Record 4 of Set 9 | uusikaupunki
# Processing Record 5 of Set 9 | sao joao da barra
# Processing Record 6 of Set 9 | nueva loja
# Processing Record 7 of Set 9 | abu dhabi
# Processing Record 8 of Set 9 | volovo
# Processing Record 9 of Set 9 | arroyo
# Processing Record 10 of Set 9 | norfolk
# Processing Record 11 of Set 9 | alexandria
# Processing Record 12 of Set 9 | bonavista
# Processing Record 13 of Set 9 | natal
# Processing Record 14 of Set 9 | avera
# Processing Record 15 of Set 9 | york
# Processing Record 16 of Set 9 | kati
# Processing Record 17 of Set 9 | sihora
# Processing Record 18 of Set 9 | santa fe
# Processing Record 19 of Set 9 | ferme-neuve
# Processing Record 20 of Set 9 | killybegs
# Processing Record 21 of Set 9 | ejura
# Processing Record 22 of Set 9 | huntington
# Processing Record 23 of Set 9 | kapuskasing
# Processing Record 24 of Set 9 | ilulissat
# Processing Record 25 of Set 9 | cockburn harbour
# City not found. Skipping...
# 'coord'
# Processing Record 26 of Set 9 | mrirt
# City not found. Skipping...
# 'coord'
# Processing Record 27 of Set 9 | ingleside
# Processing Record 28 of Set 9 | lakhdenpokhya
# Processing Record 29 of Set 9 | zhigansk
# Processing Record 30 of Set 9 | ixtapa
# Processing Record 31 of Set 9 | los llanos de aridane
# Processing Record 32 of Set 9 | bengkulu
# Processing Record 33 of Set 9 | lolua
# City not found. Skipping...
# 'coord'
# Processing Record 34 of Set 9 | mawlaik
# Processing Record 35 of Set 9 | manbij
# Processing Record 36 of Set 9 | wanning
# Processing Record 37 of Set 9 | youhao
# Processing Record 38 of Set 9 | new haven
# Processing Record 39 of Set 9 | nizhniy kuranakh
# Processing Record 40 of Set 9 | grand river south east
# City not found. Skipping...
# 'coord'
# Processing Record 41 of Set 9 | mount gambier
# Processing Record 42 of Set 9 | ushtobe
# Processing Record 43 of Set 9 | aykhal
# Processing Record 44 of Set 9 | ormara
# Processing Record 45 of Set 9 | cruz alta
# Processing Record 46 of Set 9 | vitim
# Processing Record 47 of Set 9 | kerouane
# Processing Record 48 of Set 9 | wajima
# Processing Record 49 of Set 9 | saint-pierre
# Processing Record 50 of Set 9 | kilindoni
# Processing Record 1 of Set 10 | opuwo
# Processing Record 2 of Set 10 | sinjai
# Processing Record 3 of Set 10 | college
# Processing Record 4 of Set 10 | alice springs
# Processing Record 5 of Set 10 | vila franca do campo
# Processing Record 6 of Set 10 | pulivendla
# Processing Record 7 of Set 10 | kholm
# Processing Record 8 of Set 10 | kot diji
# Processing Record 9 of Set 10 | lucea
# Processing Record 10 of Set 10 | bubaque
# Processing Record 11 of Set 10 | toliary
# City not found. Skipping...
# 'coord'
# Processing Record 12 of Set 10 | burkhala
# City not found. Skipping...
# 'coord'
# Processing Record 13 of Set 10 | kloulklubed
# Processing Record 14 of Set 10 | sartell
# Processing Record 15 of Set 10 | kota belud
# Processing Record 16 of Set 10 | kieta
# Processing Record 17 of Set 10 | roma
# Processing Record 18 of Set 10 | senno
# Processing Record 19 of Set 10 | rock sound
# Processing Record 20 of Set 10 | suzu
# City not found. Skipping...
# 'coord'
# Processing Record 21 of Set 10 | korla
# Processing Record 22 of Set 10 | pozo colorado
# Processing Record 23 of Set 10 | port hawkesbury
# Processing Record 24 of Set 10 | saint-leu
# Processing Record 25 of Set 10 | samoded
# Processing Record 26 of Set 10 | tidore
# City not found. Skipping...
# 'coord'
# Processing Record 27 of Set 10 | oga
# Processing Record 28 of Set 10 | mareeba
# Processing Record 29 of Set 10 | umm kaddadah
# Processing Record 30 of Set 10 | north bend
# Processing Record 31 of Set 10 | gonzales
# Processing Record 32 of Set 10 | luz
# Processing Record 33 of Set 10 | louisbourg
# City not found. Skipping...
# 'coord'
# Processing Record 34 of Set 10 | nemuro
# Processing Record 35 of Set 10 | kautokeino
# Processing Record 36 of Set 10 | panama city
# Processing Record 37 of Set 10 | galeana
# Processing Record 38 of Set 10 | puerto baquerizo moreno
# Processing Record 39 of Set 10 | san andres
# Processing Record 40 of Set 10 | puerto del rosario
# Processing Record 41 of Set 10 | piterka
# Processing Record 42 of Set 10 | chateauneuf-les-martigues
# Processing Record 43 of Set 10 | bhander
# Processing Record 44 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 10 | haines junction
# Processing Record 46 of Set 10 | maniitsoq
# Processing Record 47 of Set 10 | saint-gilles
# Processing Record 48 of Set 10 | urubicha
# Processing Record 49 of Set 10 | daru
# Processing Record 50 of Set 10 | nyurba
# Processing Record 1 of Set 11 | bay roberts
# Processing Record 2 of Set 11 | vallenar
# Processing Record 3 of Set 11 | lagoa
# Processing Record 4 of Set 11 | sabha
# Processing Record 5 of Set 11 | bontang
# Processing Record 6 of Set 11 | talnakh
# Processing Record 7 of Set 11 | gazanjyk
# Processing Record 8 of Set 11 | tura
# Processing Record 9 of Set 11 | xining
# Processing Record 10 of Set 11 | fornosovo
# Processing Record 11 of Set 11 | tazovskiy
# Processing Record 12 of Set 11 | mayumba
# Processing Record 13 of Set 11 | bogashevo
# Processing Record 14 of Set 11 | yakeshi
# Processing Record 15 of Set 11 | wilmington
# Processing Record 16 of Set 11 | magrath
# Processing Record 17 of Set 11 | baruun-urt
# Processing Record 18 of Set 11 | rahuri
# Processing Record 19 of Set 11 | suez
# Processing Record 20 of Set 11 | aksarayskiy
# Processing Record 21 of Set 11 | carballo
# Processing Record 22 of Set 11 | lasa
# Processing Record 23 of Set 11 | lahij
# Processing Record 24 of Set 11 | yaring
# Processing Record 25 of Set 11 | jardim
# Processing Record 26 of Set 11 | araceli
# Processing Record 27 of Set 11 | grand centre
# City not found. Skipping...
# 'coord'
# Processing Record 28 of Set 11 | takoradi
# Processing Record 29 of Set 11 | neuquen
# Processing Record 30 of Set 11 | elizabeth city
# Processing Record 31 of Set 11 | skegness
# Processing Record 32 of Set 11 | udachnyy
# Processing Record 33 of Set 11 | almaznyy
# Processing Record 34 of Set 11 | vastervik
# City not found. Skipping...
# 'coord'
# Processing Record 35 of Set 11 | nanakuli
# Processing Record 36 of Set 11 | sao jose da coroa grande
# Processing Record 37 of Set 11 | novosergiyevka
# Processing Record 38 of Set 11 | cortez
# Processing Record 39 of Set 11 | turukhansk
# Processing Record 40 of Set 11 | orchard homes
# Processing Record 41 of Set 11 | addis abeba
# Processing Record 42 of Set 11 | marv dasht
# City not found. Skipping...
# 'coord'
# Processing Record 43 of Set 11 | bhatkal
# Processing Record 44 of Set 11 | ayolas
# Processing Record 45 of Set 11 | poya
# Processing Record 46 of Set 11 | athabasca
# Processing Record 47 of Set 11 | poum
# Processing Record 48 of Set 11 | sieradz
# Processing Record 49 of Set 11 | ruatoria
# City not found. Skipping...
# 'coord'
# Processing Record 50 of Set 11 | saint-francois
# Processing Record 1 of Set 12 | uwayl
# City not found. Skipping...
# 'coord'
# Processing Record 2 of Set 12 | abashiri
# Processing Record 3 of Set 12 | marienburg
# Processing Record 4 of Set 12 | kushima
# Processing Record 5 of Set 12 | qax
# Processing Record 6 of Set 12 | dauphin
# Processing Record 7 of Set 12 | siva
# Processing Record 8 of Set 12 | emerald
# Processing Record 9 of Set 12 | san felipe
# Processing Record 10 of Set 12 | marzuq
# Processing Record 11 of Set 12 | allapalli
# Processing Record 12 of Set 12 | epernay
# Processing Record 13 of Set 12 | ust-koksa
# Processing Record 14 of Set 12 | riyadh
# Processing Record 15 of Set 12 | arlit
# Processing Record 16 of Set 12 | egvekinot
# Processing Record 17 of Set 12 | leh
# Processing Record 18 of Set 12 | vite
# Processing Record 19 of Set 12 | bulgan
# Processing Record 20 of Set 12 | tartagal
# Processing Record 21 of Set 12 | omboue
# Processing Record 22 of Set 12 | humberto de campos
# Processing Record 23 of Set 12 | jieshi
# Processing Record 24 of Set 12 | lubango
# Processing Record 25 of Set 12 | novyy urengoy
# Processing Record 26 of Set 12 | adre
# Processing Record 27 of Set 12 | inhambane
# Processing Record 28 of Set 12 | narsaq
# Processing Record 29 of Set 12 | hokitika
# Processing Record 30 of Set 12 | breytovo
# Processing Record 31 of Set 12 | inuvik
# Processing Record 32 of Set 12 | hovd
# Processing Record 33 of Set 12 | ajdabiya
# Processing Record 34 of Set 12 | hasaki
# Processing Record 35 of Set 12 | brae
# Processing Record 36 of Set 12 | najran
# Processing Record 37 of Set 12 | morro bay
# Processing Record 38 of Set 12 | alyangula
# Processing Record 39 of Set 12 | oriximina
# Processing Record 40 of Set 12 | macau
# Processing Record 41 of Set 12 | lloydminster
# Processing Record 42 of Set 12 | taunggyi
# Processing Record 43 of Set 12 | dombarovskiy
# Processing Record 44 of Set 12 | hue
# Processing Record 45 of Set 12 | saint simons
# Processing Record 46 of Set 12 | rawlins
# Processing Record 47 of Set 12 | rio gallegos
# Processing Record 48 of Set 12 | nueva concepcion
# Processing Record 49 of Set 12 | lumeje
# Processing Record 50 of Set 12 | sarangani
# Processing Record 1 of Set 13 | akdepe
# Processing Record 2 of Set 13 | ulaanbaatar
# Processing Record 3 of Set 13 | marcona
# City not found. Skipping...
# 'coord'
# Processing Record 4 of Set 13 | rudnogorsk
# Processing Record 5 of Set 13 | arbagar
# Processing Record 6 of Set 13 | dumas
# Processing Record 7 of Set 13 | lantawan
# Processing Record 8 of Set 13 | bilma
# Processing Record 9 of Set 13 | grand-lahou
# Processing Record 10 of Set 13 | potosi
# Processing Record 11 of Set 13 | san pedro de ycuamandiyu
# Processing Record 12 of Set 13 | san cristobal
# Processing Record 13 of Set 13 | bairiki
# Processing Record 14 of Set 13 | constitucion
# Processing Record 15 of Set 13 | krasnyy chikoy
# Processing Record 16 of Set 13 | tabialan
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 13 | buraydah
# Processing Record 18 of Set 13 | bonfim
# Processing Record 19 of Set 13 | ganzhou
# Processing Record 20 of Set 13 | argir
# Processing Record 21 of Set 13 | zeya
# Processing Record 22 of Set 13 | kulykiv
# Processing Record 23 of Set 13 | giaginskaya
# Processing Record 24 of Set 13 | tarudant
# City not found. Skipping...
# 'coord'
# Processing Record 25 of Set 13 | diffa
# Processing Record 26 of Set 13 | palimbang
# Processing Record 27 of Set 13 | kijang
# Processing Record 28 of Set 13 | saurimo
# Processing Record 29 of Set 13 | port-cartier
# Processing Record 30 of Set 13 | dordrecht
# Processing Record 31 of Set 13 | yorkton
# Processing Record 32 of Set 13 | belaya gora
# Processing Record 33 of Set 13 | gomel
# Processing Record 34 of Set 13 | naze
# Processing Record 35 of Set 13 | vardo
# Processing Record 36 of Set 13 | ankazobe
# Processing Record 37 of Set 13 | chazuta
# Processing Record 38 of Set 13 | bobcaygeon
# Processing Record 39 of Set 13 | hinatuan
# Processing Record 40 of Set 13 | luau
# Processing Record 41 of Set 13 | iwanai
# Processing Record 42 of Set 13 | shirvan
# Processing Record 43 of Set 13 | toamasina
# Processing Record 44 of Set 13 | auki
# Processing Record 45 of Set 13 | pangnirtung
# Processing Record 46 of Set 13 | harrison
# Processing Record 47 of Set 13 | perth
# Processing Record 48 of Set 13 | alappuzha
# Processing Record 49 of Set 13 | presidencia roque saenz pena
# Processing Record 50 of Set 13 | paso de carrasco
# Processing Record 1 of Set 14 | kitob
# Processing Record 2 of Set 14 | nuristan
# Processing Record 3 of Set 14 | tabiauea
# City not found. Skipping...
# 'coord'
# Processing Record 4 of Set 14 | vaitape
# Processing Record 5 of Set 14 | leshukonskoye
# Processing Record 6 of Set 14 | kozyatyn
# Processing Record 7 of Set 14 | sao benedito do rio preto
# Processing Record 8 of Set 14 | nago
# Processing Record 9 of Set 14 | sept-iles
# Processing Record 10 of Set 14 | toccoa
# Processing Record 11 of Set 14 | guarapari
# Processing Record 12 of Set 14 | jam sahib
# Processing Record 13 of Set 14 | sorong
# Processing Record 14 of Set 14 | portland
# Processing Record 15 of Set 14 | chicama
# Processing Record 16 of Set 14 | zarate
# Processing Record 17 of Set 14 | eureka
# Processing Record 18 of Set 14 | ludvika
# Processing Record 19 of Set 14 | jinchengjiang
# City not found. Skipping...
# 'coord'
# Processing Record 20 of Set 14 | phanat nikhom
# Processing Record 21 of Set 14 | oistins
# Processing Record 22 of Set 14 | marinhais
# Processing Record 23 of Set 14 | stoyba
# City not found. Skipping...
# 'coord'
# Processing Record 24 of Set 14 | vao
# Processing Record 25 of Set 14 | bugiri
# Processing Record 26 of Set 14 | key west
# Processing Record 27 of Set 14 | vuktyl
# Processing Record 28 of Set 14 | kualakapuas
# Processing Record 29 of Set 14 | kuldiga
# Processing Record 30 of Set 14 | bayangol
# Processing Record 31 of Set 14 | awjilah
# Processing Record 32 of Set 14 | el cope
# Processing Record 33 of Set 14 | nishihara
# Processing Record 34 of Set 14 | rokytnice nad jizerou
# Processing Record 35 of Set 14 | arvika
# Processing Record 36 of Set 14 | camopi
# Processing Record 37 of Set 14 | kodinsk
# Processing Record 38 of Set 14 | leczyca
# Processing Record 39 of Set 14 | noumea
# Processing Record 40 of Set 14 | cumaribo
# City not found. Skipping...
# 'coord'
# Processing Record 41 of Set 14 | bonwapitse
# Processing Record 42 of Set 14 | nizhniy kislyay
# Processing Record 43 of Set 14 | comodoro rivadavia
# Processing Record 44 of Set 14 | akyab
# Processing Record 45 of Set 14 | sira
# Processing Record 46 of Set 14 | aksha
# Processing Record 47 of Set 14 | orahovac
# Processing Record 48 of Set 14 | tonota
# Processing Record 49 of Set 14 | yerbogachen
# Processing Record 50 of Set 14 | golden
# Processing Record 1 of Set 15 | cacequi
# Processing Record 2 of Set 15 | ugoofaaru
# Processing Record 3 of Set 15 | moindou
# Processing Record 4 of Set 15 | aksarka
# Processing Record 5 of Set 15 | los alamos
# Processing Record 6 of Set 15 | hinton
# Processing Record 7 of Set 15 | necochea
# Processing Record 8 of Set 15 | la esperanza
# Processing Record 9 of Set 15 | bohodukhiv
# Processing Record 10 of Set 15 | imbituba
# Processing Record 11 of Set 15 | kailua
# Processing Record 12 of Set 15 | shelburne
# Processing Record 13 of Set 15 | intipuca
# Processing Record 14 of Set 15 | novosokolniki
# Processing Record 15 of Set 15 | victor harbor
# Processing Record 16 of Set 15 | udomlya
# Processing Record 17 of Set 15 | liberal
# Processing Record 18 of Set 15 | seymchan
# Processing Record 19 of Set 15 | bolanos de calatrava
# Processing Record 20 of Set 15 | czersk
# Processing Record 21 of Set 15 | derzhavinsk
# Processing Record 22 of Set 15 | ayan
# Processing Record 23 of Set 15 | uray
# Processing Record 24 of Set 15 | manicore
# Processing Record 25 of Set 15 | caravelas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df=pd.DataFrame(city_data)
new_column_order=['City','Country',"Lat",'Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
city_data_df=city_data_df[new_column_order]
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0    severo-kurilsk      RU  50.6789  156.1250     53.58        90
# 1      san patricio      US  28.0170  -97.5169     86.86        71
# 2              hilo      US  19.7297 -155.0900     72.81        90
# 3         busselton      AU -33.6500  115.3333     53.10        84
# 4          la ronge      CA  55.1001 -105.2842     66.45        63
# ..              ...     ...      ...       ...       ...       ...
# 666     derzhavinsk      KZ  51.1000   66.3167     74.62        28
# 667            ayan      RU  56.4500  138.1667     62.92        83
# 668            uray      RU  60.1247   64.7758     66.92        63
# 669        manicore      BR  -5.8092  -61.3003     80.55        83
# 670       caravelas      BR -17.7125  -39.2481     77.88        58
#
#      Cloudiness  Wind Speed Current Description
# 0            17       10.96          few clouds
# 1            37        4.43    scattered clouds
# 2            75        4.61       broken clouds
# 3             0        8.72           clear sky
# 4            20        5.75          few clouds
# ..          ...         ...                 ...
# 666           7        3.09           clear sky
# 667          86        2.93     overcast clouds
# 668         100        5.84     overcast clouds
# 669          40        6.91    scattered clouds
# 670           3        6.04           clear sky
#
# [671 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
